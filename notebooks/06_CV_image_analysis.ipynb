# %% [markdown]
# merge img url to cleaned final dataset
# san diego only

# %% [markdown]
# “Does visual presentation appear to add useful signal beyond price, location, amenities, and host quality?”

# %% [markdown]
# Run CV on one city.
# Create visual_quality_score.
# Merge it back to listings by id.
# Compare demand by visual score quartile.
# Optional: add visual score to the model and see whether performance improves.

# %%
Extract simple visual features first:

Feature	Meaning
Brightness	Are photos light/dark?
Sharpness	Are photos blurry or crisp?
Color saturation	Do photos feel vivid or flat?
Warmth	Do photos feel warm/inviting?
Image count	How many listing images exist?
Interior/exterior proxy	Optional, only if feasible
Visual quality score	Composite score from above
